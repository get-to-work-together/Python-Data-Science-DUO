# %% [markdown]
# # Read csv file

# %%
import pandas as pd

# %%
filename = r'C:\Users\peter\Computrain\_InCompany\DUO\datasets\ca-500.csv' # WINDOWS!!
filename = 'C:\\Users\\peter\\Computrain\\_InCompany\\DUO\\datasets\\ca-500.csv' # WINDOWS!!

filename = '../datasets/ca-500.csv'

# %%
df = pd.read_csv(filename)
df
# Out:
#     first_name   last_name                    company_name  \
# 0    Francoise     Kohlman               Riebesell, H F Jr
# 1       Kendra      Yandow               Deloitte & Touche
# 2      Lourdes     Beliles               Oklahoma Neon Inc
# 3       Hannah    Helmcamp              M B A Paint Stores
# 4          Tom       Sport       Sheraton Shreveport Hotel
# ..         ...         ...                             ...
# 495       Erin       Lafoy             Curtiss Wright Corp
# 496  Kassandra     Batdorf        Phelps Tool & Die Co Inc
# 497     Leslee  Bredernitz         Factory Mattress Outlet
# 498     Daniel      Cisney  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio       Fower      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# 1           6 Arch St #9757          Alcida       NB  E8J 2C4  506-363-1526
# ...

# %%
list(df.columns)
# Out:
# ['first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'city',
#  'province',
#  'postal',
#  'phone1',
#  'phone2',
#  'email',
#  'web',
#  'date_of_birth']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     500 non-null    object
#  1   last_name      500 non-null    object
#  2   company_name   500 non-null    object
#  3   address        500 non-null    object
#  4   city           500 non-null    object
#  5   province       500 non-null    object
#  6   postal         500 non-null    object
#  7   phone1         500 non-null    object
#  8   phone2         500 non-null    object
#  9   email          490 non-null    object
#  10  web            500 non-null    object
#  11  date_of_birth  500 non-null    object
# dtypes: object(12)
# memory usage: 47.0+ KB

# %%
df[df['email'].isna()]
# Out:
#     first_name last_name                   company_name  \
# 207       Long      Lehn              Georgetown Agency
# 209      Lucia    Weekly                       Days Inn
# 215     Nickie   Marrano       Mcinerney Communications
# 258   Bethanie     Pritt         Four Star Label Co Inc
# 281       Sina    Norcia          Misioneros Del Camino
# 319    Shanice    Vosmus      Firm Security Systems Inc
# 323      Essie  Montalgo             Artistic Gifts Inc
# 422     Verona   Staiano               M C Green & Sons
# 425        Nan   Shufelt  Kates Boylston Publicatns Inc
# 487     Annice     Wykle            Hering, Glenn Z Esq
#
#                    address             city province   postal        phone1  \
# 207           8 W 41st Ave       Blainville       QC  J7C 2R9  450-771-5010
# 209          196 Touhy Ave      Scarborough       ON  M1E 3L6  416-870-8070
# 215   7 Saint Nicholas Ave  North Vancouver       BC  V7J 3P8  604-556-1080
# ...

# %%
df.dropna()[~(df['email'].dropna().str.match(r'[\w\.]+@\w+\.\w{2,3}'))]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, company_name, address, city, province, postal, phone1, phone2, email, web, date_of_birth]
# Index: []

# %%
df['name'] = df['first_name'] + ' ' + df['last_name']

# %%
df = df.drop('name', axis='columns')

# %%
df.insert(0, 'name', df['first_name'] + ' ' + df['last_name'].str.upper())

# %%
df
# Out:
#                   name first_name   last_name                    company_name  \
# 0    Francoise KOHLMAN  Francoise     Kohlman               Riebesell, H F Jr
# 1        Kendra YANDOW     Kendra      Yandow               Deloitte & Touche
# 2      Lourdes BELILES    Lourdes     Beliles               Oklahoma Neon Inc
# 3      Hannah HELMCAMP     Hannah    Helmcamp              M B A Paint Stores
# 4            Tom SPORT        Tom       Sport       Sheraton Shreveport Hotel
# ..                 ...        ...         ...                             ...
# 495         Erin LAFOY       Erin       Lafoy             Curtiss Wright Corp
# 496  Kassandra BATDORF  Kassandra     Batdorf        Phelps Tool & Die Co Inc
# 497  Leslee BREDERNITZ     Leslee  Bredernitz         Factory Mattress Outlet
# 498      Daniel CISNEY     Daniel      Cisney  Cosgroves N End Plbg & Hdwr Co
# 499      Antonio FOWER    Antonio       Fower      Mission Lincoln Properties
#
# ...

# %%
provinces = df['province'].value_counts()
provinces
# Out:
# province
# ON    175
# QC    116
# BC     72
# AB     42
# NB     30
# NS     23
# SK     21
# MB     12
# NL      8
# PE      1
# Name: count, dtype: int64

# %%
provinces.plot(kind='barh')
# Out:
# <Axes: ylabel='province'>
